# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/Usedesk/blob/Ozerin-Nikita-branch/st_hw_1_1_test_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_excel('/content/drive/MyDrive/Витрина_Юздеск_2.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11779 entries, 0 to 11778
# Data columns (total 55 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   #NAME?                  11779 non-null  object
#  1   comp_id_new             11779 non-null  int64
#  2   месяц_desc              11779 non-null  int64
#  3   дата                    11779 non-null  datetime64[ns]
#  4   рейтинг                 11779 non-null  int64
#  5   всего                   11779 non-null  int64
#  6   есть ответ              11779 non-null  int64
#  7   выполнен                11779 non-null  int64
#  8   закрыт                  11779 non-null  int64
#  9   nps                     11779 non-null  int64
#  10  email                   11779 non-null  int64
#  11  telephony               11779 non-null  int64
#  12  api                     11779 non-null  int64
#  13  usedesk_chat            11779 non-null  int64
# ...

# %%
df.head()
# Out:
#    #NAME?  #NAME?.1  company_id  рейтинг  месяц  всего  есть ответ  выполнен  \
# 0  #NAME?       NaN           1        1      1   1110         146        40
# 1  #NAME?       NaN           1        1      2   2615         416        54
# 2  #NAME?       NaN           1        1      3   4226         639       167
# 3  #NAME?       NaN           1        1      4   3484         351        61
# 4  #NAME?       NaN           1        1      5   3950         620       117
#
#    закрыт  nps  ...  extreme  агент+  агент-  каналы+ all  каналы+ p  \
# 0     124    4  ...        0       0      14           13          1
# 1     672  101  ...        4       5       2           60         25
# 2     625  140  ...        2      11      22          101         10
# 3     685  158  ...        3       5       3           42          8
# 4     559   51  ...       13       2       0           63          9
#
#    каналы- all  каналы- p  правила_cnt  nps_cnt  nps_avg
# ...

# %%
df.describe() # std - среднее квадратичное отклонение
# Out:
#         comp_id_new    месяц_desc       рейтинг          всего     есть ответ  \
# count  11779.000000  11779.000000  11779.000000   11779.000000   11779.000000
# mean     159.161219     18.870023      1.463112   10307.243824    4857.042618
# std      121.751784     14.419856      1.009327   31165.334547   13314.351860
# min        1.000000      1.000000      0.000000       1.000000       0.000000
# 25%       54.000000      7.000000      1.000000     368.000000     145.000000
# 50%      131.000000     15.000000      1.000000    1958.000000     914.000000
# 75%      246.000000     28.000000      2.000000    7425.500000    3778.000000
# max      468.000000     61.000000      3.000000  894142.000000  348032.000000
#
#             выполнен         закрыт            nps          email  \
# count   11779.000000   11779.000000   11779.000000   11779.000000
# mean     2313.782240    5769.051363    1058.356906    3630.646744
# std      9931.106132   20178.150736    4181.018183   13208.588675
# ...

# %%
print(df.shape)
print(df.size)    #кол-во элементов
# Out:
# (11779, 55)
# 647845

# %%
df.count()        #все записи заполнены
# Out:
# #NAME?                    11779
# comp_id_new               11779
# месяц_desc                11779
# дата                      11779
# рейтинг                   11779
# всего                     11779
# есть ответ                11779
# выполнен                  11779
# закрыт                    11779
# nps                       11779
# email                     11779
# telephony                 11779
# api                       11779
# usedesk_chat              11779
# vk                        11779
# telegram                  11779
# whatsapp                  11779
# fb_instagram              11779
# chat                      11779
# instagram                 11779
# facebook                  11779
# pact_telegram_personal    11779
# twitter-mention           11779
# chat2desk                 11779
# slack_thread              11779
# twitter-direct            11779
# question                  11779
# task                      11779
# problem                   11779
# ...

# %%
df.dtypes
# Out:
# #NAME?                            object
# comp_id_new                        int64
# месяц_desc                         int64
# дата                      datetime64[ns]
# рейтинг                            int64
# всего                              int64
# есть ответ                         int64
# выполнен                           int64
# закрыт                             int64
# nps                                int64
# email                              int64
# telephony                          int64
# api                                int64
# usedesk_chat                       int64
# vk                                 int64
# telegram                           int64
# whatsapp                           int64
# fb_instagram                       int64
# chat                               int64
# instagram                          int64
# facebook                           int64
# pact_telegram_personal             int64
# twitter-mention                    int64
# ...

# %%
df.corr()
# Out:
# <ipython-input-27-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                         comp_id_new  месяц_desc   рейтинг     всего  \
# comp_id_new                1.000000   -0.406041  0.050274 -0.097537
# месяц_desc                -0.406041    1.000000  0.062635  0.009857
# рейтинг                    0.050274    0.062635  1.000000  0.079701
# всего                     -0.097537    0.009857  0.079701  1.000000
# есть ответ                -0.060921   -0.041746  0.140555  0.769969
# выполнен                  -0.104099    0.026919  0.021347  0.602674
# закрыт                    -0.071961   -0.018879  0.086551  0.836197
# nps                       -0.058255   -0.064097  0.079945  0.454097
# email                     -0.084247    0.040836  0.077043  0.647065
# ...

# %%
df_group = df.groupby(['рейтинг', 'всего']).count()
df_group
# Out:
#                 #NAME?  comp_id_new  месяц_desc  дата  есть ответ  выполнен  \
# рейтинг всего
# 0       1           39           39          39    39          39        39
#         2           42           42          42    42          42        42
#         3           20           20          20    20          20        20
#         4           22           22          22    22          22        22
#         5           29           29          29    29          29        29
# ...                ...          ...         ...   ...         ...       ...
# 3       403151       1            1           1     1           1         1
#         438135       1            1           1     1           1         1
#         448656       1            1           1     1           1         1
#         539393       1            1           1     1           1         1
#         894142       1            1           1     1           1         1
#
# ...

# %%
df['есть ответ'].head(33)
# Out:
# 0      3442
# 1      5301
# 2      5983
# 3      7664
# 4      7252
# 5      9321
# 6      9572
# 7      6390
# 8      5049
# 9      4991
# 10     4371
# 11     4320
# 12     4017
# 13     3961
# 14     4112
# 15     4677
# 16     6984
# 17     8987
# 18    10719
# 19     8984
# 20     6998
# 21     7205
# 22     6124
# 23     5444
# 24     5298
# 25     5195
# 26     6272
# 27     8613
# 28     9096
# 29    10197
# 30    12794
# 31     9260
# 32     9139
# Name: есть ответ, dtype: int64
