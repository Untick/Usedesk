# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/Usedesk/blob/Khalajyan-Elizabeth-branch/Khalajyan%20Elizabeth/%D0%A1%D1%82%D0%B0%D0%B6%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Подгрузка датасета

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('/content/Копия Витрина_Юздеск_2.xlsx - V1.csv', index_col=0)
data.head()
# Out:
#         comp_id_new  месяц_desc      дата  рейтинг  всего  есть ответ  \
# #NAME?
# #NAME?            1           1  6/1/2023        2   3709        3442
# #NAME?            1           2  5/1/2023        2   5573        5301
# #NAME?            1           3  4/1/2023        2   6138        5983
# #NAME?            1           4  3/1/2023        2   7834        7664
# #NAME?            1           5  2/1/2023        2   7344        7252
#
#         выполнен  закрыт   nps  email  ...  u-task  u_problem  u_incident  \
# #NAME?                                 ...
# #NAME?       578    2466  1231   1317  ...       0          0           0
# #NAME?        36    4715  2004   2008  ...       0          0           0
# #NAME?         4    5496  2242   1991  ...       0          0           0
# #NAME?         1    7094  2851   2519  ...       0          0           0
# #NAME?         1    6657  2686   2377  ...       0          0           0
#
# ...

# %% [markdown]
# # Исследования

# %%
data.shape #количество строк и столбцов
# Out:
# (11779, 54)

# %%
data.size #количество элементов в таблице
# Out:
# 636066

# %%
data.info #информация
# Out:
# <bound method DataFrame.info of         comp_id_new  месяц_desc      дата  рейтинг  всего  есть ответ  \
# #NAME?
# #NAME?            1           1  6/1/2023        2   3709        3442
# #NAME?            1           2  5/1/2023        2   5573        5301
# #NAME?            1           3  4/1/2023        2   6138        5983
# #NAME?            1           4  3/1/2023        2   7834        7664
# #NAME?            1           5  2/1/2023        2   7344        7252
# ...             ...         ...       ...      ...    ...         ...
# #NAME?          465           1  5/1/2023        1     11          11
# #NAME?          466           1  6/1/2023        1     88          12
# #NAME?          466           2  5/1/2023        1      7           7
# #NAME?          467           1  6/1/2023        1     57          55
# #NAME?          468           1  6/1/2023        1    121          91
#
#         выполнен  закрыт   nps  email  ...  u-task  u_problem  u_incident  \
# ...
